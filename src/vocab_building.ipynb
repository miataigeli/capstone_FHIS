# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import time

# %% [markdown]
# # A-level vocab collection

# %% [markdown]
# ## Spanish 1

# %%
soup_url = "https://en.wikiversity.org/wiki/Spanish_1"

# %%
def get_vocab_url(soup):
    """
    get a list of urls that lead to the vocabulary

    soup: (BeautifulSoup) an html parsed bs object

    return: (list) a list of urls
    """
    tag_list = soup.find("ul").findAll("a", {"href": re.compile(r"/wiki/Spanish_1/.*")})
    url_list = [
        soup_url + re.search(r'(/wiki/Spanish_1)(/.*)(" )', str(tag)).group(2)
        for tag in tag_list
        if "Linguistic_characteristics" not in str(tag)
    ]
    return url_list

# %%
soup = BeautifulSoup(urlopen(soup_url), "html.parser")
url_list = get_vocab_url(soup)

print(url_list)
# Out:
# ['https://en.wikiversity.org/wiki/Spanish_1/Countries', 'https://en.wikiversity.org/wiki/Spanish_1/The_Basics', 'https://en.wikiversity.org/wiki/Spanish_1/Activities', 'https://en.wikiversity.org/wiki/Spanish_1/Adjectives', 'https://en.wikiversity.org/wiki/Spanish_1/School', 'https://en.wikiversity.org/wiki/Spanish_1/The_Classroom', 'https://en.wikiversity.org/wiki/Spanish_1/Food_%26_Drink', 'https://en.wikiversity.org/wiki/Spanish_1/Health', 'https://en.wikiversity.org/wiki/Spanish_1/Destinations', 'https://en.wikiversity.org/wiki/Spanish_1/Recreation_%26_Lifestyle', 'https://en.wikiversity.org/wiki/Spanish_1/Family_%26_Celebrations', 'https://en.wikiversity.org/wiki/Spanish_1/Adjectives_%26_In_a_restaurant', 'https://en.wikiversity.org/wiki/Spanish_1/The_Bedroom', 'https://en.wikiversity.org/wiki/Spanish_1/The_Household', 'https://en.wikiversity.org/wiki/Spanish_1/Shopping', 'https://en.wikiversity.org/wiki/Spanish_1/At_the_Mall', 'https://en.wikiversity.org/wiki/Spanish_1/Vacation', 'https://en.wikiversity.org/wiki/Spanish_1/Community', 'https://en.wikiversity.org/wiki/Spanish_1/Television', 'https://en.wikiversity.org/wiki/Spanish_1/Computers']

# %%
def get_vocab(url):
    """
    get a list of vocabulary scraped from the url given

    url: (str) an url lead to a list of vocabulary

    return: (list) a list of Spanish words
    """
    soup = BeautifulSoup(urlopen(url), "html.parser")
    regex = re.compile(r"<b>(.*)</b>")  # extract Spanish words

    vocab_list = [
        regex.search(str(match.find("b")))
        .group(1)
        .lower()
        .split("=")[0]
        .split("-")[0]
        .strip()
        .strip(".,-=")
        .strip()
        for match in soup.findAll("li")  # find lists
        if not len(match.attrs) and match.find("b")
    ]

    
    # Expand and add most of the parenthetical constructions from the scraped vocabulary
    regex = re.compile(r"\((\w+)\)")
    for elem in vocab_list:
        search = regex.search(elem)

        if search:
            start = search.start(1)
            end = search.end(1)
            match = search.group(1)

            # Pre-strip (base case)
            elem_strip = elem[: start - 1] + elem[end + 1 :]

            # If the word in parenthesis occurs at the end of the string preceded by a space,
            # it is likely intended as extra info (eg., "baile (bailar)") and can be skipped
            if elem[start - 2] == " " and len(elem) == end + 1:
                continue

            # For constructions like "mi(s)" -> "mi" & "mis"; "tiene(n)" -> "tiene" & "tienen"
            elif match == "s" or match == "n" or match == "es":
                sub = elem[: start - 1] + match + elem[end + 1 :]

            # For constructions like "professor(ora)" -> "professor" & "professora"
            elif match == "ora":
                sub = elem[: start - len(match)] + match + elem[end + 1 :]

            # If the parentheses occur at the start of the string:
            # eg., "(los) estados unidos" -> "estados unidos" & "los estados unidos"
            elif start == 1:
                sub = match + elem[end + 1 :]
                elem_strip = elem[end + 2 :]

            # For constructions like "fantastico(a)" -> "fantastico" & "fantastica"
            elif match == "as" or match == "a" or match == "os" or match == "o":
                sub = elem[: start - 1 - len(match)] + match + elem[end + 1 :]

            # Else case: if parentheses occur somewhere in the middle of the string:
            # eg., "té (frío) helado" -> "té helado" & "té frío helado"
            else:
                sub = elem[: start - 1] + match + elem[end + 1 :]
                elem_strip = elem[: start - 2] + elem[end + 1 :]

            vocab_list.append(elem_strip)
            vocab_list.append(sub)

    # Add the constituent words in a multi-word phrase to the vocabulary
    for elem in vocab_list:
        if " " in elem:
            vocab_list.extend([e.strip("/,()") for e in elem.split(" ")])

    return vocab_list

# %%
spanish1_vocab = []
for url in url_list:
    spanish1_vocab.extend(get_vocab(url))

# %%
print(len(set(spanish1_vocab)))
# Out:
# 2298

# %%
set(spanish1_vocab)
# Out:
# {'encima de la/del ...',
#  '¿cómo te llamas?',
#  'cocina',
#  'los lunes',
#  '¡qué ...!',
#  'tecla de borrar',
#  'hay ...',
#  'yerno',
#  'calvo(a)',
#  'pensamos',
#  'escribiendo',
#  'disteis',
#  'veintiocho',
#  'sabroso(a)',
#  'bastante',
#  'cuarenta',
#  'opening marks</b>. written questions and expressions of exclamation begin with a <b>¿</b> or a <b>¡',
#  'viajar',
#  'comprender',
#  'guisantes',
#  'son las siete menos cuarto.',
#  'vender',
#  'comedia',
#  'siempre',
#  'anaranjado(a)(s)',
#  'costar',
#  'audífonos',
#  'telenovela',
#  'país',
#  'si',
#  'drama',
#  'música rap',
#  'horrible',
#  'madrastra',
#  'vengo',
#  'aburrir',
#  'deprimido(a)',
#  'zanahorias',
#  'lavar',
#  'esos, esas',
#  'dirección electrónica',
#  'guinea ecuatorial',
#  'señora (sra.)',
#  'sótano',
#  'compraste',
#  'doler',
#  'usted (ud.)',
#  '¡no me digas!',
#  '¿cómo es usted?',
#  'unos pantalones cortos',
#  'trompa de llaves',
#  'práctica de ...',
#  'planta baja',
#  'reloj',
#  'perro',
#  'unos calcetines',
#  'colores',
#  'ventana',
#  'pelo',
#  'usar la computadora',
#  'me falta(n) ...',
#  '¿eres ...?',
#  'veintidós',
#  'quitar el polvo',
#  'jugo de naranja',
#  'compraron',
#  'es',
#  'el dvd',
#  'oso polar',
#  'lo siento',
#  'sólo',
#  'punta...</b> - <b>tip',
#  'torta/tarta/pastel/bizcocho',
#  'actual = current',
#  'ellos',
#  'primero(a)',
#  'décimo(a)',
#  'chocolate caliente',
#  'comprar',
#  'programa de la vida real',
#  'panamá',
#  'me/te gustan los/las ...',
#  'vidrio',
#  'ratón',
#  'qué delicioso!',
#  'hotel',
#  'nada',
#  'programa de concursos',
#  'conoce',
#  'arreglar el cuarto',
#  'dicen',
#  'quieren',
#  'mayor',
#  'aprendí',
#  'duermes',
#  'diapositiva',
#  'patinar',
#  'papel',
#  'leer revistas',
#  '¿cómo eres?',
#  'contento(a)',
#  'lápiz / lápices',
#  'mi(s)',
#  'pelo rizado',
#  'calabaza',
#  'juego',
#  'mostaza',
#  'club',
#  'anoche',
#  'ancianos',
#  'quizás',
#  'yogur',
#  'va',
#  'novio',
#  'escribe',
#  '¿de dónde eres?',
#  'primo',
#  'detrás de mi',
#  'jugar al béisbol',
#  'chancletas',
#  'ciudad',
#  'frutas',
#  'en la ... hora',
#  'agencia de viajes',
#  'quinto(a)',
#  'mucho gusto.',
#  'cámara digital',
#  'merengue',
#  'veintiuno',
#  'sobrino',
#  'perdón.',
#  'reciclar',
#  'tigre',
#  'nuestro(s), -a(s)',
#  'desordenado(a)',
#  'conmigo',
#  'problema',
#  'montar en monopatín / patineta',
#  'me/te encanta el/la ...',
#  'para el almuerzo',
#  'noviembre',
#  'confundido(a)',
#  'pijama',
#  'esposa',
#  'enviar un correo electrónico',
#  'toca',
#  'padres',
#  'sándwich/sánduche/sánguche/emparedado',
#  'pantalla',
#  'carne de res',
#  'ave',
#  'con mis/tus amigos',
#  'papas fritas',
#  'almuerzo',
#  'escuela primaria',
#  'julio',
#  'el',
#  'juega',
#  'martes',
#  'mucho',
#  'bueno(a)',
#  'jardín',
#  'vino blanco',
#  'impresionante',
#  'jugar en el parque',
#  'patinar sobre hielo',
#  'perú',
#  '¿cómo se llama ella?',
#  'apartamento',
#  'zapatillas',
#  'comen',
#  'tuba',
#  'famosa',
#  'mochila',
#  'comer',
#  'estoy',
#  'instrumento',
#  'duerme',
#  'cuaderno',
#  'espaguetis',
#  'interesar',
#  'escribir por correo electrónico',
#  '¿qué hora es?',
#  'comiendo',
#  'usar',
#  'delante de la/del ...',
#  'son las cuatro y media.',
#  'vuestro(s), -a(s)',
#  'venezuela',
#  'a la, al',
#  'descansar',
#  'estamos',
#  'dar de comer al perro',
#  'sal',
#  'melón',
#  'lejos',
#  'estudiante',
#  'limonada',
#  'vino tinto',
#  'huevos',
#  'señorita (srta.)',
#  'los/las mejores',
#  'veintinueve',
#  'pongo',
#  'geografía',
#  'nadar',
#  'terminar',
#  'bandera',
#  'limón',
#  'foto',
#  'a mí también.',
#  'tener razón',
#  'tres',
#  'pastel',
#  'lunes',
#  'plato',
#  'anciana',
#  'cuchillo',
#  'jugué',
#  'la',
#  'estoy de acuerdo.',
#  'sí',
#  'pizarra',
#  'viene',
#  'crear',
#  'sirves',
#  'taza',
#  '¿cómo se llama él?',
#  'hablo',
#  'tostadas',
#  'queremos',
#  'dieciocho',
#  '¿quién?',
#  'lugar de interés',
#  'familia',
#  '¿cómo se llama?',
#  'novecientos(as)',
#  'para el desayuno',
#  'vino rosado',
#  'padre (papá)',
#  'soy',
#  'drinks',
#  'verde(es)',
#  'sabemos',
#  'ir de cámping (acampar)',
#  '¿qué hiciste?',
#  'cebolla',
#  'es necesario.',
#  'clase',
#  'flor',
#  'segundo(a)',
#  'programa musical',
#  '¿qué te gusta hacer?',
#  'emocionante',
#  'fue',
#  'tecla de intro',
#  'diecisiete',
#  'violín',
#  'noventa',
#  'cheques de viajero',
#  'el reloj despertador',
#  'maracas',
#  'seis',
#  'gordo(a)',
#  'compró',
#  'no le gusta ...',
#  'feo(a)',
#  'regular',
#  '¿te gusta...?',
#  'lavadero',
#  'tienda de ropa',
#  'té',
#  'popular/populares',
#  'es un(a) ...',
#  'compré',
#  'un momento',
#  'tarea',
#  'niños',
#  'libro',
#  'nueve',
#  'ensalada de frutas',
#  'fui',
#  'van',
#  'algre',
#  'fuiste',
#  'inolvidable',
#  'hablas',
#  'tengo',
#  'están',
#  'sala',
#  'se escribe ...',
#  'tocador',
#  'laboratorio',
#  'señor (sr.)',
#  'talentoso(a)',
#  'coméis',
#  'luz',
#  'mezquita',
#  'música hip-hop',
#  'doce',
#  'igualmente.',
#  '(el) borrador',
#  'león',
#  'grapas',
#  'diste',
#  'pelirrojo(a)',
#  'gracioso(a)',
#  'quinientos(as)',
#  'quiero',
#  'mesa',
#  'delfín',
#  'son las dos.',
#  'abuelos',
#  'pero',
#  'hay',
#  'hombre',
#  'nuevo(a)',
#  'historia',
#  'una',
#  'música latina',
#  'poner la mesa',
#  'parientes',
#  '¿cómo estás?',
#  'segundo piso',
#  'ir a la escuela',
#  'ir de compras',
#  'iglesia',
#  'somos',
#  'escribir cuentos',
#  'a menudo',
#  'especialmente',
#  'video',
#  'pides',
#  'frijoles',
#  'pasear en bote',
#  'fideos',
#  'quitar la nieve con la pala',
#  'sintetizador',
#  'sirvo',
#  'cuarto(a)',
#  '¿cuánto cuestan...?',
#  'españa',
#  'llevar',
#  'bolsa/bolso',
#  'vienes',
#  '¿qué más?',
#  'bonito(a)',
#  'tambor',
#  'fuisteis',
#  'ir a ...',
#  'me llamo...',
#  'vino',
#  'una chaqueta',
#  'muebles',
#  'navegar por la red',
#  'paciente',
#  'sirve',
#  'hasta mañana.',
#  'los martes',
#  'cereal',
#  'decidir',
#  'sabes',
#  'un',
#  'viernes',
#  'no me gusta...',
#  'coliflor',
#  'compartimos',
#  'en',
#  'visitar',
#  '¿cómo lo pasaste?',
#  'jugar videojuegos',
#  'todos(as)',
#  'cero',
#  'come',
#  'una sudadera',
#  'bolígrafo/pluma',
#  'amarillo(a)(s)',
#  'de la tarde',
#  'mesita',
#  'costa rica',
#  'artístico(a)',
#  'perro caliente',
#  'jugar al fútbol',
#  'muchos(as)',
#  'serio(a)',
#  'servilleta',
#  'sucio(a)',
#  '¡vamos!',
#  'detrás de ti',
#  'estudioso(a)',
#  'montar en bicicleta',
#  'excelente',
#  'hizo',
#  'globo',
#  'aprendisteis',
#  'página inicial',
#  'sacapuntas',
#  'rastrillar las hojas',
#  '¿de quién es esto?',
#  'unos, unas',
#  'pared',
#  'de plato principal',
#  'creo que ...',
#  '¿de qué color...?',
#  'templo',
#  'a ver ...',
#  'ocho',
#  'comunidad',
#  'enamorado(a)',
#  'estás',
#  'aeropuerto',
#  'propina',
#  'méxico',
#  'uruguay',
#  'usado(a)',
#  'comparten',
#  'haz',
#  'mil',
#  'iniciar sesión',
#  'silla',
#  'plato principal',
#  'gato',
#  'sigue',
#  'piensas',
#  'dormís',
#  'zapatos deportivos',
#  'lección de piano',
#  'sorprendido(a)',
#  'baño',
#  'es el ... de ...',
#  'entrar',
#  'jugar al ajedrez',
#  'duermo',
#  'guitarra',
#  'hicieron',
#  'paraguas',
#  'de',
#  'crema de cacahuates',
#  'ropa interior',
#  'cálculo',
#  'compramos',
#  'vienen',
#  'escalera',
#  'campo',
#  'película de terror',
#  'farmacia',
#  'pecas',
#  'vaso',
#  'disgustado(a)',
#  'estos, estas',
#  'después',
#  'árbol',
#  'vivir',
#  'muy',
#  'un suéter',
#  'limpiar el baño',
#  'conozco',
#  'a casa',
#  '(a + person) le gusta(n)',
#  'música bailable',
#  'berenjenas',
#  '¿verdad?',
#  'reuniones de ...',
#  'no me gusta nada...',
#  '¿dónde?',
#  'aguacate',
#  'realista',
#  'sirven',
#  'equipaje',
#  'prefiero',
#  'sabe',
#  'adiós.',
#  'bombardino',
#  'piso',
#  'me/te gusta el/la ...',
#  'negro(a)',
#  'rábano',
#  'uso lentes',
#  '¿cómo te va?',
#  'quiere decir ...',
#  'poner',
#  'preparado(a)',
#  'ochenta',
#  'sándwich de jamón y queso',
#  'hospital',
#  '¡genial!',
#  'actor',
#  'maestro, maestra',
#  'creo que no.',
#  'tarde',
#  'hijos',
#  'ir de vacaciones',
#  'podemos',
#  'refresco',
#  'cuenta',
#  'visitar un museo',
#  'once',
#  '¿cuál es el precio?',
#  '¿y usted?',
#  'nosotros',
#  'amigo',
#  '¿por qué?',
#  'bailar',
#  '¿cómo está usted?',
#  'pan',
#  'langosta',
#  'generalmente',
#  '¿a qué hora?',
#  'ensalada',
#  'rojo(a)(s)',
#  'mascota(s)',
#  'accents',
#  'en la esquina',
#  'pupitre',
#  'impresora',
#  'ver una película',
#  'me pasa la/el',
#  'hoy',
#  'azul oscuro',
#  'servís',
#  'tomar un curso',
#  'sinagoga',
#  'el pie = the foot',
#  'zoológico',
#  'jugar al vóleibol',
#  'carpeta',
#  'lee',
#  'gráficos',
#  'abril',
#  'dinero',
#  'piden',
#  'pingüino',
#  '¿qué te gusta más?',
#  'álgebra',
#  'ustedes (uds.)',
#  '¿y a ti?',
#  'muchacho',
#  'complicado(a)',
#  'lámpara',
#  'traer',
#  'ochocientos(as)',
#  'quitar los platos de la mesa',
#  'imprimir',
#  '¿cuánto cuesta...?',
#  'botella de vidrio',
#  'cerca',
#  'remolacha',
#  'salí',
#  'diecinueve',
#  'tocáis',
#  'cómico(a)',
#  'té (frío) helado',
#  'pájaro',
#  'hipopótamo',
#  'película de ciencia ficción',
#  'comparto',
#  'lechuga',
#  'oboe',
#  'presentación',
#  'refrigerador',
#  'tocar',
#  'piscina',
#  'ordenador',
#  'allí</b> - <b>allá',
#  'menor',
#  'durar',
#  'cara a cara',
#  'me gusta más...',
#  'sobre',
#  'cortar el césped (la grama)',
#  'barco',
#  'mesonera',
#  'cantar',
#  'al lado de la/del ...',
#  'cocinar',
#  'música rock',
#  'gracias.',
#  'cama',
#  'setenta',
#  'arándano',
#  'caro(a)',
#  'malo(a)',
#  'pueden',
#  'voy',
#  'helado',
#  'estáis',
#  'tiene(n) ... años.',
#  'las',
#  'equipo de sonido',
#  'disco compacto',
#  'francés',
#  'porque',
#  'pez',
#  'clase de ...',
#  'para mí',
#  'a mí',
#  'despacho, la oficina',
#  'abuelo',
#  'lavaplatos',
#  'dices',
#  'alemán',
#  'pienso',
#  'pan tostado',
#  'una camiseta',
#  'encantado(a).',
#  'levantar pesas',
#  'grabar un disco compacto',
#  'me gusta mucho...',
#  'negro(a)(s)',
#  'salisteis',
#  'pasteles',
#  'es la una.',
#  '¿cómo se escribe ...?',
#  'cuchara',
#  'rosado(a)(s)',
#  'castaño',
#  'mesero',
#  'azul marino',
#  'siete',
#  'ocupado(a)',
#  'más/menos de',
#  'estante',
#  'quehaceres',
#  'lavando',
#  'foca',
#  'música romántica',
#  'lago',
#  'piña',
#  'amiga',
#  'tren',
#  'mirar',
#  'pasar la aspiradora',
#  'salsa tártara',
#  'no estoy de acuerdo.',
#  'judías (frijoles) verdes',
#  'unos pantalones',
#  'venado',
#  'dieciséis',
#  'red social',
#  'beber',
#  'tomar el sol en la playa',
#  'pera',
#  'me/te encantan los/las ...',
#  'chivo',
#  'venimos',
#  '¿y tú?',
#  'necesito comprar...',
#  'me queda(n) bien/mal.',
#  'tecnología',
#  'ponche de frutas',
#  'blanco(a)(s)',
#  'película policíaca',
#  'decimos',
#  'serpiente',
#  '¿a qué hora ....?',
#  'trabajo',
#  '¡bien!',
#  'ecuador',
#  'aprendiste',
#  'correr',
#  'buen mozo(a)',
#  'pequeño(a)',
#  'venís',
#  'escalar las montañas',
#  'sigo',
#  'creer',
#  '(el) lápiz',
#  'ellas',
#  'un traje de baño',
#  'salir',
#  'coco',
#  'gris(es)',
#  'fantastico(a)',
#  'dormitorio',
#  'mujer',
#  '(a + person) le encanta(n)',
#  'marrón, marrones, café',
#  'a la izquierda',
#  'jugar al básquetbol (baloncesto)',
#  'tu',
#  'unas botas',
#  'tercero(a)',
#  'anciano',
#  'romper',
#  'sesenta',
#  'corto(a)',
#  'buenos días.',
#  'sigues',
#  'me gusta...',
#  'naranjas',
#  'sociable',
#  'estudiar',
#  'pollo',
#  'curso',
#  'leche',
#  'banda',
#  'un poco',
#  'hurón',
#  '(los) lápices',
#  'cine',
#  'hablar por teléfono',
#  'disco',
#  'aprendió',
#  'esquiar',
#  'camarero',
#  'tío',
#  'pagué',
#  '¿qué?',
#  'bigote',
#  'lindo(a)',
#  'saco',
#  'anciano(a)',
#  'economía',
#  'sacar la basura',
#  'siguen',
#  'mantequilla',
#  'dos',
#  'queréis',
#  'fascinante',
#  'cada día</b> - everyday <b>todos los días',
#  'su(s)',
#  'conejillo de indias',
#  'azul claro',
#  'tremendo(a)',
#  'carta',
#  'sabéis',
#  'digo',
#  'comunicarse',
#  'con',
#  'almejas',
#  'bello(a)',
#  'padrastro',
#  'coleccionar monedas',
#  'museo',
#  'pensáis',
#  'encantar',
#  'latín',
#  'a mí tampoco.',
#  'interesante',
#  'hicimos',
#  'hamburguesa',
#  'azúcar',
#  'ayudar',
#  'tortuga',
#  'fresas',
#  'música clásica',
#  'habla',
#  'camarera',
#  'juguete',
#  'me',
#  'café',
#  'salió',
#  'tener frío',
#  'ciencias naturales',
#  'tenemos',
#  'programa educativo',
#  'necesito',
#  'en ...',
#  'hija',
#  'televisor',
#  'un vestido',
#  'colombia',
#  'buenas tardes.',
#  'estufa',
#  '¡uf!',
#  'según mi familia',
#  'juegan',
#  'infantil',
#  'barrio / urbanización / vecindario',
#  '¿en qué puedo servirle?',
#  'septiembre',
#  'vi',
#  'honduras',
#  'hice',
#  'todos los días',
#  '(los) estados unidos',
#  'playa',
#  'tenéis',
#  'misterioso(a)',
#  'salsa de tomate',
#  '¿qué quiere decir ...?',
#  'habláis',
#  'más o menos',
#  'nieta',
#  'cosa',
#  'veinte',
#  'ciencias sociales',
#  'preocupado(a)',
#  'por eso',
#  '¿me trae ...?',
#  'famoso',
#  'tengo hambre.',
#  'podéis',
#  'prima',
#  'veintisiete',
#  'favorito(a)',
#  'teclado',
#  'queso',
#  'ayer',
#  'bisabuela',
#  'parque de diversiones',
#  'conocemos',
#  'nieto',
#  'perezoso(a)',
#  'banco',
#  'prefieren',
#  'ciruela',
#  'música reggeton',
#  'pepinos',
#  'actriz',
#  'inglés',
#  'nunca',
#  'a la derecha',
#  'montañas',
#  'hacer un video',
#  'banana',
#  'comprasteis',
#  'a su servicio.',
#  'veinticinco',
#  'triste',
#  'me comunico',
#  'salimos',
#  'tener miedo',
#  'durante',
#  'arroz',
#  'soda',
#  'tarjeta',
#  'veintitrés',
#  'sobrina',
#  'pido',
#  'gimnasio',
#  'ir de pesca',
#  'información',
#  'hablamos',
#  '¿cuáles?',
#  'cortinas',
#  'el/la peor',
#  'anuario',
#  'supermercado',
#  'miércoles',
#  'quién',
#  'armario',
#  'uno',
#  'jugamos',
#  'repollo',
#  'calle',
#  'postre',
#  'más ... que',
#  'note',
#  'prefiere',
#  'una camisa',
#  'duermen',
#  'piñata',
#  'cumbia',
#  'de la mañana',
#  'chico',
#  'tocan',
#  'temprano',
#  'busqué',
#  'haces',
#  'noveno(a)',
#  'unos zapatos',
#  'puerto rico',
#  'el/la mejor',
#  'película romántica',
#  'verdura',
#  'cincuenta',
#  'hace (+ time expression)',
#  'fue un desastre.',
#  'página web',
#  'estadio',
#  'comer en el restaurante',
#  '¿cuándo?',
#  'joven',
#  'jueves',
#  'tenedor',
#  'le',
#  'decorar',
#  'le gusta ...',
#  'cocodrilo',
#  'quieres',
#  'frustrado(a)',
#  'puedes',
#  'demasiado',
#  'ante de',
#  'boleto',
#  'te',
#  'hoja de papel',
#  'dar',
#  'paraguay',
#  'comemos',
#  'caja',
#  '¿cómo es?',
#  'conocen',
#  'panqueque',
#  'en casa',
#  'cereza',
#  'demás',
#  'química',
#  'loro',
#  'veintiséis',
#  'bien',
#  'jugo de manzana',
#  'baile (bailar)',
#  'precio',
#  'cambur',
#  '¿adónde?',
#  'recibir',
#  'argentina',
#  'escritorio',
#  'fueron',
#  'me gustó.',
#  'pobre',
#  'mas...que',
#  'viaje',
#  'soy ...',
#  'música jazz',
#  'calabacín',
#  'comida',
#  'tienda',
#  'guineo',
#  'papel picado/papelillo',
#  'chile',
#  'espárragos',
#  'pantimedias',
#  'enfermo(a)',
#  'doscientos(as)',
#  'fuimos',
#  'hicisteis',
#  'sitio web',
#  '¡qué asco!',
#  '¿qué te parece?',
#  'acordeón',
#  'una gorra',
#  'saben',
#  'dio',
#  'música folclórica',
#  'obra de teatro',
#  'pasar tiempo con amigos / amistades',
#  'hermanastro',
#  'pimentón/pimientos',
#  'aburrido(a)',
#  'tener sed',
#  'cordero',
#  'hermana',
#  'el blues',
#  'bajo(a)',
#  'ya',
#  'octubre',
#  'arte',
#  'fantástico(a)',
#  '¿qué estás haciendo?',
#  'quitar',
#  'tiene',
#  'según',
#  'fácil',
#  'enojado(a)',
#  'limpio(a)',
#  'carpeta de argollas',
#  'bucear',
#  'sabroso/sabrosos',
#  'semana pasada',
#  'sandía',
#  'reservado(a)',
#  'los, las',
#  'mimosa',
#  'jugar al golf',
#  'por supuesto',
#  'necesitas',
#  'solo(a)',
#  'hiciste',
#  'este, esta',
#  'cebra',
#  'compartís',
#  'servimos',
#  'puede',
#  'emocionado(a)',
#  'se dice...',
#  '¿qué hora es, por favor?',
#  'difícil',
#  'visitar salas de chat',
#  'sois',
#  'queso crema',
#  'bistec',
#  'octavo(a)',
#  'conejo',
#  'agosto',
#  'puerta',
#  'aquí',
#  'hermanastra',
#  'vamos',
#  'monumento',
#  'ese, esa',
#  'cerveza',
#  'secadora',
#  'canal',
#  'tortas mexicanas',
#  'niño',
#  'cereales',
#  'sábado',
#  ...}

# %% [markdown]
# ## Spanish 2

# %%
soup_url = "https://en.wikiversity.org/wiki/Spanish_2"

# %%
# Remake function for use with Spanish 2 Wikiversity
def get_vocab_url(soup):
    """
    get a list of urls that lead to the vocabulary

    soup: (BeautifulSoup) an html parsed bs object

    return: (list) a list of urls
    """
    tag_list = soup.find("ul").findAll(
        "a", {"href": re.compile(r"/wiki/Spanish_2/Chapter.*")}
    )
    url_list = [
        soup_url + re.search(r'(/wiki/Spanish_2)(/Chapter.*)(" )', str(tag)).group(2)
        for tag in tag_list
    ]
    return url_list

# %%
soup = BeautifulSoup(urlopen(soup_url), "html.parser")
url_list = get_vocab_url(soup)

print(url_list)
# Out:
# ['https://en.wikiversity.org/wiki/Spanish_2/Chapter_1_(Classroom_Events)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_2_(Free_Time)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_3_(Daily_Activities)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_4_(Fashion)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_5_(Errands)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_6_(On_the_Road)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_7_(Childhood)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_8_(Celebrations)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_9_(Emergencies)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_10_(Accidents)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_11_(Television)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_12_(Movies)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_13_(Cooking)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_14_(Picnics)', 'https://en.wikiversity.org/wiki/Spanish_2/Chapter_15_(Planning_a_trip)']

# %%
spanish2_vocab = []
for url in url_list:
    spanish2_vocab.extend(get_vocab(url))

# %%
print(len(set(spanish2_vocab)))
# Out:
# 1754

# %%
set(spanish2_vocab)
# Out:
# {'',
#  'ese, esa',
#  'ningún, ninguna',
#  'página',
#  'los, las',
#  'sombra de ojos',
#  'sombra',
#  'chocar con',
#  'erupción volcánica',
#  'atleta',
#  'loca',
#  'no...todavía',
#  'haz',
#  'peluquería',
#  'despegar',
#  'con',
#  'carne',
#  'tranquilo(a)',
#  'leí',
#  'asar',
#  'poniendo',
#  'estáis',
#  'costumbre',
#  'besarse',
#  'espinacas',
#  'llenar',
#  'valentín',
#  'mercado',
#  'presentador, presentadora',
#  'bajo',
#  'traiga',
#  'hacer un picnic',
#  'cumplir años',
#  'creyendo',
#  'temprano',
#  'tobillo',
#  'uñas',
#  'detalles',
#  'sabor',
#  'veía',
#  'nevar',
#  'prefirió',
#  'educada',
#  'salud',
#  'vuelta',
#  'colección',
#  'rota',
#  'vencer',
#  'aduana',
#  'está hecho de',
#  'está',
#  'prestar atención',
#  'exagerado',
#  'vivía',
#  'director, directora',
#  'inyección',
#  '¿qué tal es...?',
#  'miré',
#  'quema',
#  'edificio',
#  'cayó',
#  'ensayo',
#  'inquieto(a)',
#  'empecé',
#  'de niño',
#  'pequeño(a',
#  'campeón',
#  'director',
#  'se',
#  'vivían',
#  'decir',
#  'emocionado(a)',
#  'salsa de tomate',
#  'has',
#  'jugaban',
#  'canción',
#  'juguetón',
#  'uniforme',
#  'hace...?',
#  'va...?',
#  'salida de emergencia',
#  'llamar',
#  'regalo',
#  'nunca',
#  'estés',
#  'aprendamos',
#  'hacían',
#  'cajero',
#  'coma(n)',
#  'marcador',
#  'habléis',
#  'estuvimos',
#  'me/te importa',
#  'fogata',
#  'saludarse',
#  'cuenta',
#  'ciclón',
#  'dar un discurso',
#  'ladrón',
#  'correo urgente',
#  'parece',
#  'pastillas',
#  'pusierion',
#  'patio de recreo',
#  'harina',
#  'salones',
#  'meter un gol',
#  'día',
#  'puede',
#  'examen (el)',
#  'ese',
#  'entienden',
#  'tuviste',
#  'papel',
#  'importan',
#  'suelo',
#  'timida',
#  'palo de golf',
#  'tratar',
#  'frito',
#  'peligroso',
#  'nada',
#  'y',
#  'izquierda',
#  'lesión',
#  'exploradora',
#  'presentadora',
#  'cuidar a',
#  'veías',
#  'cocido',
#  'prestar',
#  'a causa de',
#  'al',
#  'felicitar',
#  'balón',
#  'reunirse',
#  'caminata',
#  'herida',
#  'ayuda',
#  'que...?',
#  'hacer un viaje',
#  'caigo',
#  'hacer una búsqueda',
#  'te acuestas',
#  'vivíais',
#  'tos',
#  'extracurriculares',
#  'está hecha de',
#  'millón/milliones',
#  'robar',
#  'puso',
#  'lápiz de labios',
#  'automático',
#  'hockey',
#  'asistir',
#  'volver',
#  'cinturón',
#  'íbamos',
#  'eras',
#  'miraste',
#  'devuelto',
#  'olvides',
#  'traigan',
#  'aquel, aquella',
#  '¿de',
#  'amor',
#  'crudo',
#  'golf',
#  'estuvisteis',
#  'pasatiempo',
#  'sartén',
#  'baja',
#  'aguacate',
#  'aficionada',
#  'fotógrafa',
#  'ladrona',
#  'pedisteis',
#  'club atlético',
#  'almuerzas',
#  'ir a pie',
#  'asustado(a)',
#  'almuerza',
#  'abordar',
#  'estar resfriado',
#  'cumplir',
#  'sobrino',
#  'cirujano',
#  'ser miembro',
#  'siempre',
#  'locutor(ora)',
#  'hacer gimnasia',
#  'mayonesa',
#  'sala',
#  'cepillarse',
#  'dicho',
#  'derecho',
#  'conoce',
#  'nos acostamos',
#  'des',
#  'pintarse',
#  'dejar',
#  'monstruo',
#  'parar',
#  'pronto',
#  'vuelo',
#  'cuñada',
#  'maíz',
#  'paella',
#  'no des',
#  'de prisa',
#  'fruta de estación',
#  'participar',
#  'creyó',
#  'reportera',
#  'darse',
#  'las',
#  'mediano',
#  'compartimiento sobre la cabeza',
#  'hasta',
#  'tener éxito',
#  'vecino',
#  'efectos especiales',
#  'maquinilla',
#  'dijimos',
#  'esta',
#  'leíste',
#  'asada',
#  'sandía',
#  'último(a)',
#  'comenzar',
#  'último',
#  'enamorado',
#  'se cierra',
#  'actividades extracurriculares',
#  'pobrecita',
#  'están',
#  'músico',
#  'ponerse',
#  'la verdad',
#  'carrusel',
#  'aprendáis',
#  'dar una caminata',
#  'moneda',
#  'hacía',
#  'artes',
#  'acuerdo',
#  'centro cultural',
#  'se cayó',
#  '<i>noun</i>',
#  'en vivo',
#  'cuidar',
#  'cheque',
#  'apagar',
#  'acostáis',
#  '¿cómo se hace...?',
#  'jóvenes',
#  'era',
#  'accesible',
#  'emocionado',
#  'sin',
#  'festivo',
#  'jugar',
#  'pasado',
#  'esos',
#  'suyo (a',
#  'despacio',
#  'destruisteis',
#  'emergencia',
#  'dijo',
#  'esmalte',
#  'acostarse',
#  'pudieron',
#  'puente',
#  'loco(a',
#  'héroe',
#  'mentiroso',
#  'tuvimos',
#  '¿verdad?',
#  'grapadora',
#  'investigar',
#  'llegar tarde',
#  'creativo(a)',
#  'reportero',
#  'oscuro',
#  'cayeron',
#  'mojada',
#  'patines',
#  'dijieron',
#  'me/te',
#  'tomar lecciones',
#  'peces',
#  'abrocharse el cinturón',
#  'frita',
#  'leyeron',
#  'nota',
#  'reina',
#  'prestado',
#  'juguetona',
#  'flojo(a)',
#  'tener prisa',
#  'película de acción',
#  'sabéis',
#  'ventanilla',
#  'gol',
#  'tuve',
#  'generoso(a)',
#  'de repente',
#  'guante de béisbol',
#  'tela sintética',
#  'ducha',
#  'tiza',
#  'campeonato',
#  'visitar',
#  'escribió',
#  'explorador',
#  'oro',
#  'conductor',
#  'estén',
#  'toalla',
#  'pisapapeles',
#  'grasoso',
#  'análisis',
#  'entendéis',
#  'labios',
#  'añadas',
#  'acuestan',
#  'ir',
#  'delincuente',
#  'destruyeron',
#  'cerrada',
#  'resumen',
#  'dije',
#  'asustado',
#  'arena',
#  'incendio',
#  'oliva',
#  'bajar',
#  'bien educado(a)',
#  'hacia',
#  'me/te importan',
#  'alrededor de',
#  'pidió',
#  'boda',
#  'yeso',
#  'enamorarse',
#  'reunión',
#  'apartamentos',
#  'necesitar',
#  'gimnasia',
#  'apretado',
#  'receta',
#  'panadería',
#  'me estás poniendo nervioso',
#  'ciruela',
#  'repiten',
#  'cocida',
#  'creyeron',
#  'navegar',
#  'saluda',
#  'anillo',
#  'ajedrez',
#  'triciclo',
#  'sobrina',
#  'pasajero(a)',
#  'se cayeron',
#  'nieta',
#  'congelado(a)',
#  'puerta',
#  'quemar(se)',
#  'acompañar',
#  'estar basado',
#  'destruir',
#  'se murieron',
#  'estar basada',
#  'urgente',
#  'caja',
#  'bebé',
#  'tan (+ adjective)',
#  'examen',
#  'los',
#  'humectante',
#  'estar segura',
#  'educado(a',
#  'viajero',
#  'patio',
#  'has visto',
#  'añadir',
#  'salida',
#  'seguro(a',
#  'sintética',
#  'cupón',
#  'deportivo',
#  'modales',
#  'creísteis',
#  'saludar(se)',
#  'agencia',
#  'agencia de viajes',
#  'ha estudiado',
#  'terremoto',
#  'freír',
#  'gallina',
#  'escribamos',
#  'conejo',
#  'romperse',
#  'chuleta de cerdo',
#  'carta',
#  'dental',
#  'almorzamos',
#  'bolos',
#  'asustada',
#  'dejes',
#  'cesta',
#  'ensayar',
#  'volverse loca',
#  'tripulación',
#  'fumar',
#  'entre',
#  'nunca jamás',
#  'viniste',
#  'de vez en cuando',
#  'dé',
#  'dulce',
#  'nos',
#  'ancho(a)',
#  'esté, estén',
#  'liquidación',
#  'aprendas',
#  'consentido',
#  'fascinar',
#  'cambio',
#  'abre',
#  'enlatada',
#  'agrio(a)',
#  'dentro',
#  'hacíais',
#  'entiende',
#  'viajes',
#  '¿cómo',
#  'prestada',
#  'médica',
#  'carretera',
#  'te ves',
#  'tarjeta',
#  'correo',
#  'público',
#  'tren eléctrico',
#  'huracán',
#  'recomendar',
#  'interés',
#  'juguete',
#  'pequeña',
#  'estuve',
#  'puse',
#  'juguetón, juguetona',
#  'asilo para ancianos',
#  'escalera',
#  'oscuro(a)',
#  'pude',
#  'pasta',
#  'servicio',
#  'contestar',
#  'fuente',
#  'tenga, tengan',
#  'engrapadora',
#  'desfile',
#  'informe',
#  'coro',
#  'varios',
#  'resfriado',
#  'zorro',
#  'lavarse',
#  'ibas',
#  'llevarse',
#  'no comas',
#  'portarse',
#  'guardería',
#  'manejar',
#  'frecuentemente',
#  'al horno',
#  'almuerzan',
#  'pregunta',
#  'entendemos',
#  'trajo',
#  'eléctrico',
#  'ladrón, ladrona',
#  'hemos',
#  'nadie',
#  'habéis',
#  'seco(a)',
#  'jugabais',
#  'pasó?',
#  'nacer',
#  'conocemos',
#  'parada',
#  'darse la mano',
#  'ningún',
#  'éramos',
#  'gastar',
#  'mojado(a)',
#  'dormimos',
#  'antibiótico',
#  'caramba',
#  'entrevista',
#  'retraso',
#  'agitado(a)',
#  'señal de parada',
#  'cirujano(a)',
#  'se acuestan',
#  'bandita',
#  'oímos',
#  'viaje',
#  'jugador',
#  'coman',
#  '¡qué lástima!',
#  'preferir',
#  'bien educado',
#  'llegada',
#  'este, esta',
#  'le',
#  'sentirse',
#  'supermercado',
#  'colonia',
#  'empezaste',
#  'olvidó',
#  'muebles',
#  'crítico',
#  'oído',
#  'pupitre',
#  'pudo',
#  '¿de qué está hecho?',
#  'estos',
#  'anunciar',
#  'poner',
#  'crudo(a)',
#  'hasta pronto',
#  'excursionista',
#  'molestar',
#  'sonreír',
#  'dormisteis',
#  'tomar apuntes',
#  'calles',
#  'general',
#  'sugerir',
#  'reírse',
#  'prestado(a',
#  'todo el mundo',
#  'ninguno',
#  'principal',
#  'carne de res',
#  'conductor(ora)',
#  'almohada',
#  'llover',
#  'herido(a)',
#  'medicina',
#  'timido(a)',
#  'bien/mal',
#  'desodorante',
#  'enojado(a)',
#  'de',
#  'poner una inyección',
#  'al final',
#  'mayores',
#  'de niña',
#  'bombero',
#  'premio',
#  'tomar',
#  'me',
#  'cuerda',
#  'farmacia',
#  'competir',
#  'con destino a',
#  'espuma',
#  'se acuesta',
#  'derrumbe',
#  'fiebre',
#  'artes marciales',
#  'trayendo',
#  'muletas',
#  'ha',
#  'evento especial',
#  'enfermero',
#  'expedición',
#  'pasado(a',
#  'natación',
#  'raqueta',
#  'enamorado(a',
#  'guante',
#  'desde',
#  'llevarse bien/mal',
#  'nuestro',
#  'jabón',
#  'olor',
#  'locutor',
#  'vino',
#  'algún, alguna, algunos',
#  'año',
#  'memorizar',
#  'jamás',
#  '¡basta!',
#  'pedí',
#  'crear',
#  'traiga, traigan',
#  'agua de colonia',
#  'pudiste',
#  'aficionado(a)',
#  'agente de viajes',
#  'escriba',
#  'escoger',
#  'no escribas',
#  'durmió',
#  'traje',
#  'almorcé',
#  'loción',
#  'frito(a)',
#  'segura',
#  'años',
#  'casco',
#  'jugabas',
#  'despertarse',
#  'no!',
#  'vida',
#  'furioso',
#  'letrero',
#  'pedir prestado',
#  'tijeras',
#  'identificación',
#  'marca',
#  'aprenda',
#  'éxito',
#  'estación de servicio',
#  'concurso',
#  'fresco',
#  'estilo',
#  'escritorio',
#  'complicado(a)',
#  'destruyó',
#  'roto(a)',
#  'lástima!',
#  'insistir',
#  'de niño(a)',
#  'muñeco',
#  'niña',
#  'informe (el)',
#  'volverse loco',
#  'del',
#  'fuiste',
#  'conocéis',
#  'ancianos',
#  'encender',
#  'dormido(a)',
#  'palabra',
#  'conocen',
#  'fijador',
#  'pedir prestada',
#  'diciendo',
#  'pie',
#  'de pequeño',
#  'casarse',
#  'bate de béisbol',
#  'mariscos',
#  'dinosaurio',
#  'volcánica',
#  'explicar',
#  'víspera del año nuevo',
#  'hoja',
#  'bautizo',
#  'músico(a)',
#  'sorpresa',
#  'sangre',
#  'feliz',
#  'esquina',
#  'obediente',
#  'coma',
#  'pusiste',
#  'aprendieron',
#  'rápidamente',
#  'picnic',
#  'escribáis',
#  'estar de moda',
#  'repente',
#  'orquesta',
#  'actuación',
#  'tortuga',
#  'venda',
#  'lluvia',
#  'cómodo',
#  'salón',
#  'ningún, ninguno(a)',
#  'loco',
#  'durar',
#  'tifón',
#  'preferisteis',
#  'hacer',
#  'de sólo un color',
#  'enamorado(a) de',
#  'columpio',
#  'zorra',
#  'no estés',
#  'furiosa',
#  'me caigo',
#  'pasar',
#  'escala',
#  'grabar',
#  'ruedas',
#  'mediana',
#  'de ida y vuelta',
#  'esmalte de uñas',
#  '¿cuánto tiempo hace que...?',
#  'plaza',
#  'músculo',
#  'dijisteis',
#  'tropezar',
#  'buena',
#  'flojo',
#  'tantas',
#  'salvar',
#  'crítico(a)',
#  'se prohíbe',
#  'obedecer',
#  'anuncio',
#  'mostaza',
#  'déjame en paz',
#  'bien educada',
#  'astringente',
#  'entregar',
#  'valiente',
#  'erais',
#  'día festivo',
#  'erupción',
#  'festival de cine',
#  'pobrecito',
#  'esquí/de',
#  'oís',
#  'de pequeña',
#  'pudisteis',
#  'empezamos',
#  'recreo',
#  'camarón',
#  'chorizo',
#  'animador',
#  'san',
#  'ibais',
#  'seas',
#  'enlatado(a)',
#  'especial',
#  '¿qué te parece?',
#  'veíamos',
#  'adhesiva',
#  'coleccionar',
#  'ninguno(a',
#  'palo',
#  'bienvenida',
#  'cinta adhesiva',
#  'paramédica',
#  'estoy',
#  'consentido(a)',
#  'ingrediente',
#  'preferimos',
#  'algunos(as',
#  'animadoa',
#  'paisaje',
#  'web',
#  'cajero(a)',
#  'leyendo',
#  'iban',
#  'lentamente',
#  'congelado',
#  'oíste',
#  'dijiste',
#  'a',
#  'carnet',
#  'documental',
#  'complicada',
#  'empleado',
#  'importa(n',
#  'exagerado(a)',
#  'te caes',
#  'frijoles',
#  'anotar',
#  'sabemos',
#  'exagerada',
#  'rana',
#  'procedente de',
#  'centro',
#  'dientes',
#  'tires',
#  'mojado',
#  'volverse loco(a)',
#  'cajero automático',
#  'saqué',
#  'pasta dental',
#  'estrecho',
#  'jugoso',
#  'aplaudir',
#  'estrecho(a)',
#  'comido',
#  'tantas + <i>noun</i> + como',
#  '¿con qué se sirve?',
#  'se abre',
#  'anteojos de esquí/de natación',
#  'personaje principal',
#  'cordero',
#  'estar en línea',
#  'traviesa',
#  'ayuntamiento',
#  'tener paciencia',
#  'repito',
#  'hubo',
#  'res',
#  'cocido(a)',
#  'apio',
#  'puerta de embarque',
#  'tirar',
#  'bate',
#  'tela',
#  'silla',
#  'fuera',
#  'caldo',
#  'médico',
#  'auxiliar',
#  'maquillaje',
#  'os acostáis',
#  'fotógrafo',
#  'vistiendo',
#  'vivías',
#  'pelearse',
#  'torneo',
#  'pudimos',
#  'entrenadora',
#  'siguiendo',
#  'víctima',
#  'hecha?',
#  'creíste',
#  'meter',
#  'olla',
#  'veíais',
#  'calentar',
#  'cortarse',
#  'tomar nota',
#  'cinta',
#  'leña',
#  'esas',
#  'papelería',
#  'facturar',
#  'cerdo',
#  'fue',
#  'saltar',
#  'pedir ayuda',
#  'bandito',
#  'espárragos',
#  'crear una página web',
#  'cerrado(a)',
#  'estos, estas',
#  'empiezas',
#  'tienda de acampar',
#  'aprendan',
#  'maquinilla  de afietar',
#  'complicado',
#  'semáforo',
#  'escribí',
#  'comas',
#  'rodilla',
#  'hacer escala',
#  'culpable',
#  '¿de qué está hecho(a)?',
#  'pelo',
#  'a tiempo',
#  'tempestad',
#  'memoria',
#  'seda',
#  '+',
#  'maremoto',
#  'pidiendo',
#  'directo(a)',
#  'escribiste',
#  'realidad',
#  'auxiliar de vuelo',
#  'chocar',
#  'enviar',
#  'quitar',
#  'apuntes',
#  'nervioso(a',
#  'aprendió',
#  'buzón',
#  'lana',
#  'sea',
#  'práctica',
#  'morirse',
#  'eran',
#  'pedimos',
#  'congelada',
#  'entrevistar',
#  'prudente',
#  'oí',
#  'tuyo',
#  'al aire libre',
#  'fósforo',
#  'eres',
#  'hemos estudiado',
#  'aprendimos',
#  'parrilla',
#  'probar',
#  'secarse',
#  'ambulancia',
#  'nieto',
#  'afeitar',
#  'dar puntadas',
#  'apretado(a)',
#  'cerrar',
#  'fresca',
#  'causa',
#  'inspección',
#  'no añadas',
#  'vinimos',
#  'fuegos artificiales',
#  'he visto',
#  'vivo',
#  'olvidarse',
#  'abrocharse',
#  'es...?',
#  'locutora',
#  'estar basado(a)',
#  'tuvieron',
#  'uniforme del equipo',
#  'alegre',
#  'empleado(a)',
#  'han estudiado',
#  'trofeo',
#  'audición',
#  'prisa',
#  'devolver',
#  'viva',
#  'furioso(a)',
#  'línea',
#  'repetís',
#  'es',
#  'ida',
#  'loción para después de afeitarse',
#  'hace tiempo que',
#  'reflexionar',
#  'vuestro (a',
#  'leísteis',
#  'leímos',
#  'embarque',
#  'estufa',
#  'infantil',
#  'lápiz',
#  'línea aérea',
#  'iba',
#  'tal',
#  'dirección',
#  'estatua',
#  'peatón',
#  'aéreo',
#  'bailarína',
#  'travieso(a)',
#  'ningún, ninguno',
#  'sujetapapeles',
#  'tranquila',
#  'directo',
#  'algodón',
#  'estrecha',
#  'tratar de',
#  'les',
#  'alergia',
#  'cruce de calles',
#  'aduanera',
#  'agradecer',
#  'pastel',
#  '¿de qué está hecha?',
#  'seco',
#  'apretada',
#  'cita',
#  'desobediente',
#  'dar',
#  'borrador',
#  'por...vez',
#  'grasoso(a)',
#  'azafrán',
#  'me estás poniendo nervioso(a)',
#  'hace tiempo',
#  'estar pasada de moda',
#  'béisbol',
#  'subibaja',
#  'avenida',
#  'medio',
#  'mentirosa',
#  'para',
#  'tiempo',
#  'refrigerador',
#  'cómodo(a)',
#  'se me olvidó',
#  'bailarín, bailarína',
#  'comentario',
#  'he estudiado',
#  'hecha',
#  'planear',
#  '¡cómo no!',
#  'jarabe',
#  'cuando',
#  ...}

# %% [markdown]
# ## Gutenberg: An elementary spanish reader

# %%
soup_url = 'https://www.gutenberg.org/files/22065/22065-h/22065-h.htm#VOCABULARY'

# %%
def get_vocab(url):
    '''
    get a list of vocabulary scraped from the url given
    
    url: (str) an url lead to a list of vocabulary
    
    return: (list) a list of Spanish words
    '''
    soup = BeautifulSoup(urlopen(url), 'html.parser')
    
    return [str(tag.string) for tag in soup.find('ul').findAll('b') if str(tag.string) != str(tag.string).upper()]

# %%
gutenberg_elementary_vocab = get_vocab(soup_url)

# %%
print(len(set(gutenberg_elementary_vocab)))
set(gutenberg_elementary_vocab)
# Out:
# 2257
# {'alazán',
#  'abrasando',
#  'sombra',
#  'tristeza',
#  'con',
#  'setenta',
#  'carne',
#  'señora',
#  'huerto',
#  'medias',
#  'panal',
#  'insistió',
#  'pudieran Vds',
#  'primor',
#  'adiestrarse',
#  'aguardar',
#  'comprar',
#  'después de',
#  'juzgado',
#  'miedo',
#  'estado',
#  'obtener',
#  'venida',
#  'bajo',
#  'lleve',
#  'traiga',
#  'contento',
#  'creyendo',
#  'poseo',
#  'por eso',
#  'espantarse',
#  'vale',
#  'aprendido',
#  'pudiera',
#  'hermoso',
#  'camino',
#  'temprano',
#  'batalla',
#  'preguntaron',
#  'daré',
#  'nevar',
#  'resistencia',
#  'se confesaba',
#  'tigre',
#  'se acercó',
#  'habitante',
#  'meneo',
#  'primero',
#  'qué tal',
#  'pedido',
#  'vuelta',
#  'ciento',
#  'envidioso',
#  'hallando',
#  'tengo',
#  'continuar',
#  'vencer',
#  'halló',
#  'falda',
#  'está',
#  'pareció',
#  'sorprendió',
#  'escuchar',
#  'vivía',
#  'ni',
#  'durante',
#  'mal',
#  'contestación',
#  'mandar quemar',
#  'despierta',
#  'frío',
#  'sobre todo',
#  'acierta',
#  'Jalma',
#  'prisionero',
#  'edificio',
#  'cayó',
#  'sabido',
#  'dispuso',
#  'se',
#  'tierra',
#  'vivían',
#  'doscientos',
#  'queriendo',
#  'comprador',
#  'montar',
#  'bígamo',
#  'dudo',
#  'decir',
#  'instante',
#  'otro',
#  'cuarenta',
#  'servirá',
#  'rienda',
#  'haré',
#  'has',
#  'minuto',
#  'dedo',
#  'ayudar',
#  'escribir',
#  'dejan',
#  'flor',
#  'ocurrido',
#  'treinta y cinco',
#  'a punto de',
#  'encuentren',
#  'verás',
#  'penoso',
#  'manifestar',
#  'efigie',
#  'príncipe',
#  'Bolondrón',
#  'cierto',
#  'encierro',
#  'conducir',
#  'llamar',
#  'regalo',
#  'nunca',
#  'entonces',
#  'asustar',
#  'remendar',
#  'comprender',
#  'obsequiar a porfía',
#  'haga',
#  'examinaron',
#  'morirás',
#  'veloz',
#  'ten',
#  'galopar',
#  'cuenta',
#  'herir',
#  'Ll',
#  'dado',
#  'resoplido',
#  'bramar',
#  'esperaba',
#  'ladrón',
#  'perdóneme Vd.',
#  'agudo',
#  'prometió',
#  'maniatado',
#  'brazo',
#  'parece',
#  'tercer',
#  'una vez',
#  'alguno',
#  'día',
#  'puede',
#  'si',
#  'término',
#  'hablaron',
#  'tomarse',
#  'remediar',
#  'Carcabuey',
#  'ese',
#  'llamaré',
#  'remozar',
#  'empezar',
#  'hallado',
#  'suelo',
#  'sesenta',
#  'fiel',
#  'árbol',
#  'alcalde',
#  'aplaude',
#  'necio',
#  'transformar',
#  'tratar',
#  'noviembre',
#  'novio',
#  'ganaba',
#  'ponderado',
#  'Julieta',
#  'comprendió',
#  'salga bien o mal',
#  'afán',
#  'espantar',
#  'favorable',
#  'siéntate',
#  'nada',
#  'y',
#  'convertirse',
#  'suma',
#  'prestar',
#  'a causa de',
#  'al',
#  'de ordinario',
#  'pueblo',
#  'dígale',
#  'infame',
#  'gran',
#  'José',
#  'volvamos',
#  'precedido',
#  'sacó',
#  'si yo pudiera',
#  'perdonar',
#  'familia',
#  'otra vez',
#  'buscar',
#  'lanza',
#  'ciudad',
#  'cambiaba',
#  'utilidad',
#  'negro',
#  'robar',
#  'guarde',
#  'pasmaron',
#  'blando',
#  'remozarán',
#  'puso',
#  'carbonero',
#  'cuándo',
#  'ganso',
#  'usura',
#  'confesar',
#  'debían',
#  'animal',
#  'don',
#  'quemar',
#  'Se lo doy',
#  'volver',
#  'hu-u-u-u',
#  'sirviente',
#  'diversión',
#  'aciertan',
#  'honor',
#  'se lo',
#  'gris',
#  'trató',
#  'resignarse',
#  'rodeaban',
#  'infinito',
#  'salía',
#  'Aliatar',
#  'invasión',
#  'solo',
#  'andar',
#  'buscado',
#  'bastante',
#  'estimar',
#  'abeja',
#  'los pobres',
#  'tanto',
#  'hablaban',
#  'Isabel',
#  'despertar',
#  'jefe',
#  'palacio',
#  'siempre',
#  'precioso',
#  'tunante',
#  'sala',
#  'dicho',
#  'preceder',
#  'pillar',
#  'derecho',
#  'menearse',
#  'negocios',
#  'yo',
#  'conoce',
#  'tú',
#  'prometí',
#  'curar',
#  'sed',
#  'quieto',
#  'dejar',
#  'atreverse',
#  'de aquesta',
#  'provisto',
#  'plebeyo',
#  'pronto',
#  'vuelo',
#  'en ninguna parte',
#  'cerca de',
#  'merece',
#  'señor',
#  'casar',
#  'hi',
#  'confesaba',
#  'hace frío',
#  'volvía',
#  'duro',
#  'las',
#  'mediano',
#  'dirigir',
#  'emperador',
#  'hasta',
#  'rodeado',
#  'joven',
#  'desesperarse',
#  'parecerse a',
#  'oyó las dos',
#  'siguieron',
#  'porqué',
#  'sostener',
#  'esta',
#  'dejas',
#  'para siempre',
#  'mieses',
#  'mil',
#  'comenzar',
#  'por entonces',
#  'concederé',
#  'por la noche',
#  'raza',
#  'último',
#  'tener palabra',
#  'junto a',
#  'bajaron',
#  'están',
#  'llegué a dudar',
#  'ponerse',
#  'fortuna',
#  'acercar',
#  'hacía',
#  'moneda',
#  'despachar',
#  'que sea',
#  'anoche',
#  'arquitecto',
#  'echarse',
#  'llevando',
#  'sostenían',
#  'llorando',
#  'ahogar',
#  'déme de cenar',
#  'regaló',
#  'desea',
#  'inundar',
#  'preguntar',
#  'era',
#  'gobernador',
#  'vio',
#  'sin',
#  'también',
#  'bah',
#  'pasado',
#  'buscó',
#  'usted',
#  'colocó',
#  'diez',
#  'irritar',
#  'nada podían',
#  'parecían',
#  'destreza',
#  '-a',
#  'dijo',
#  'dirigió',
#  'acostarse',
#  'asnal',
#  'reloj',
#  'matrimonio',
#  'caluroso',
#  'Vds.',
#  'esconderé',
#  'decidió',
#  'menospreciar',
#  'dirán',
#  'árabe',
#  'oscuro',
#  'trazar',
#  'visitó',
#  'vencido',
#  'encerrado',
#  'suponer',
#  'quitó',
#  'mírenlo Vds.',
#  'yendo',
#  'toque',
#  'hallo',
#  'las de',
#  'peinar',
#  'habilidad',
#  'despertó',
#  'puñal',
#  'largo',
#  'suerte',
#  'derramaban',
#  'por último',
#  'hacen',
#  'el mío',
#  'tener prisa',
#  'comparar',
#  'compra',
#  'compasión',
#  'cucú',
#  'cuestión',
#  'entender',
#  'mayor',
#  'robado',
#  'sabía',
#  'amigablemente',
#  'respondió',
#  'parecer',
#  'prometido',
#  'aprisionasen',
#  'mona',
#  'persiguieron',
#  'ahora',
#  'bienes',
#  'escribió',
#  'visitar',
#  'dormía',
#  'que salga',
#  'oro',
#  'libren',
#  'ustedes',
#  'conseguir',
#  'veras',
#  'reconoces',
#  'gustaron',
#  'como mi abuelo',
#  'molinero',
#  'cuchillo',
#  'podemos',
#  'meditar',
#  'cincuenta',
#  'adentro',
#  'amordazar',
#  'irse',
#  'hirió',
#  'ir',
#  'venden',
#  'acepto',
#  'no hay que one',
#  'obedeció',
#  'vieja',
#  'consistir',
#  'servir de',
#  'lavaba',
#  'lacre',
#  'asustado',
#  'marinero',
#  'coger de',
#  'en sueños',
#  'bajar',
#  'borracho',
#  'colocar',
#  'enemigo',
#  'fugarse',
#  'sucedió',
#  'aceptar',
#  'hacia',
#  'fuerte',
#  'doy',
#  'jardín',
#  'recibirá',
#  'pidió',
#  'adiestrar',
#  'de quien',
#  'las dos',
#  'tienes',
#  'ventana',
#  'casaron',
#  'demás',
#  'elemento',
#  'noventa',
#  'necesitar',
#  'cortedad',
#  'patata',
#  'médico tunante',
#  'acerca de',
#  'desarmado',
#  'arruinado',
#  'aliento',
#  'paso',
#  'contra',
#  'creyeron',
#  'mango',
#  'viendo',
#  'tarea',
#  'aunque',
#  '3 pl. fut. ind. of',
#  'cinco',
#  'vestido',
#  'Lamsaco',
#  'fingir',
#  'puerta',
#  'menear',
#  'cargó',
#  'compañero',
#  'abrieron',
#  'habrán',
#  'van',
#  'cree',
#  'prendero',
#  'vive',
#  'acompañar',
#  'dócil',
#  'cómo le va',
#  'consentimiento',
#  'pícaro',
#  'gamo',
#  'río',
#  'sonó',
#  'próximo',
#  'presencia',
#  'mozo',
#  'hubo de exclamar',
#  'seguía',
#  'nombrado',
#  'señalando',
#  'hidalguía',
#  'advertir',
#  'merecer',
#  'el de',
#  'consistía',
#  'recoger',
#  'examen',
#  'escritor',
#  'hacer de persona',
#  'desaprobar',
#  'trajese',
#  'sentía',
#  'los',
#  'tenga sabido',
#  'por entre',
#  'patio',
#  'carroza',
#  'tener sed',
#  'quejido',
#  'escuadrón',
#  'me he perdido',
#  'esposa',
#  'meterse',
#  'añadir',
#  'liebre',
#  'arreglar',
#  'poco antes',
#  'aplauden',
#  'dinero',
#  'duerme',
#  'erección',
#  'supremo',
#  'Cándido',
#  'gallina',
#  'pluma',
#  'conejo',
#  'daba',
#  'efecto',
#  'afanarse',
#  'fabricas',
#  'impetuosísimo',
#  'carta',
#  'cenar',
#  'izquierdo',
#  'tercero',
#  'entró',
#  'ya lo creo',
#  'esperaré',
#  'hará',
#  'ensayar',
#  'entre',
#  'sería',
#  'famoso',
#  'dé',
#  'mirando',
#  'nos',
#  'golpe',
#  'uvas',
#  'muchas veces',
#  'orilla',
#  'seguido',
#  'desear',
#  'conmovió',
#  'trabajar',
#  'tome',
#  'flor de lis',
#  'cambio',
#  'abre',
#  'a pesar de',
#  'abrasar',
#  'cruzase',
#  'bordado',
#  'encontraron',
#  'seguían',
#  'llevaré',
#  'transformado',
#  'insaciable',
#  'eso',
#  'luchar',
#  'perdido',
#  'imposible',
#  'hacer la corte',
#  'carretera',
#  'escondido',
#  'interpretar',
#  'llamó',
#  'falta',
#  'doce',
#  'conoció',
#  'presentaba',
#  'interés',
#  'verá',
#  'loro',
#  'estuve',
#  'obligar',
#  'informarse',
#  'guardia',
#  'feria',
#  'tontería',
#  'maniatar',
#  'escalera',
#  'menor',
#  'barranco',
#  'reposaba',
#  'colono',
#  'servicio',
#  'leer',
#  'majestad',
#  'contestar',
#  'vivir',
#  'tras',
#  'seguido de',
#  'cara',
#  'sudor',
#  'peligro',
#  'hablando',
#  'poner en libertad',
#  'cuchara',
#  'amiga',
#  'invento',
#  'cubría',
#  'llevarse',
#  'obligó',
#  'debemos',
#  'beber',
#  'tener hambre',
#  'esperando',
#  'esto',
#  'encuentran',
#  'pregunta',
#  'trajo',
#  'llevaba',
#  'nadie',
#  'vuelva',
#  'envejecer',
#  'cornisa',
#  'revuelta',
#  'conocerá',
#  'importar',
#  'asegurar',
#  'abrazo',
#  'fastidioso',
#  'canto',
#  'venga',
#  'tronco',
#  'guapo',
#  'han de',
#  'hizo',
#  'alabar',
#  'hablar',
#  'ah',
#  'entre sí',
#  'gastar',
#  'oficial',
#  'mujer',
#  'colmillo',
#  'recluta',
#  'siete',
#  'rudamente',
#  'destinado',
#  'volar',
#  'pasó',
#  'sacudir',
#  'descansar',
#  'norte',
#  'ofrecieron',
#  'toma',
#  'oleaje',
#  'lamento',
#  'pensaba',
#  'no olvide Vd.',
#  'muchísimo',
#  'ponerse en camino',
#  'preferir',
#  'haces',
#  'probado',
#  'torrente',
#  'acertar',
#  'le',
#  'moribundo',
#  'dió',
#  'disputa',
#  'muebles',
#  'olvidó',
#  'Cabra',
#  'agujero',
#  'pudo',
#  'sonrió',
#  'amigo',
#  'bendición',
#  'favor',
#  'poner',
#  'llovía',
#  'canjear',
#  'escribe',
#  'vendría',
#  'tener mucha hambre',
#  'juez',
#  'pato',
#  'dan',
#  'flauta',
#  'encantamiento',
#  'siempre que',
#  'mira',
#  'ninguno',
#  'principal',
#  'comprendo',
#  'consentir',
#  'llover',
#  'calla',
#  'pasearse',
#  'marcharon',
#  'medicina',
#  'soldado',
#  'guisado',
#  'comerciante',
#  'tapar',
#  'declaró',
#  'voy',
#  'de',
#  'rey',
#  'por todas partes',
#  'promesa',
#  'refirieron',
#  'cogió',
#  'ellos',
#  'pájaro',
#  'que Alá los guarde',
#  'obra',
#  'tomar',
#  'horma',
#  'ponderar',
#  'entra',
#  'me',
#  'llevar',
#  'cansa',
#  'empuñó',
#  'estanque',
#  'hallar',
#  'monte',
#  'conceder',
#  'quieres',
#  'comparación',
#  'condición',
#  'matasiete',
#  'confesábase',
#  'pagó',
#  'semana',
#  'hacía sol',
#  'dar un paso',
#  'hijo menor',
#  'jabalí',
#  'a donde',
#  'ha',
#  'podenco',
#  'gordo',
#  'suspirar',
#  'no ... ya',
#  'silbo',
#  'sopa',
#  'haga Vd.',
#  'desde',
#  'bajó',
#  'arma',
#  'explicó',
#  'llegue',
#  'nuestro',
#  'de la misma manera',
#  'sino',
#  'carga',
#  'emplear',
#  'mirada',
#  'aprobar',
#  'vino',
#  'echar sus cuentas',
#  'cédula',
#  'Loja',
#  'año',
#  'senda',
#  'vario',
#  'cenizas',
#  'al llegar',
#  'nombre',
#  'consejo',
#  'soler',
#  'jamás',
#  'dices',
#  'aquí',
#  'moro',
#  'ochenta',
#  'escriba',
#  'de tal modo',
#  'escoger',
#  'escondió',
#  'media noche',
#  'hospitalidad',
#  'detiene',
#  'forman',
#  'embarcar',
#  'hable Vd.',
#  'planté',
#  'probó',
#  'tan pronto como',
#  'flanco',
#  'pintor',
#  'tenerse',
#  'siguiente',
#  'caricia',
#  'vida',
#  'furioso',
#  'motivo',
#  'aqueste',
#  'letrero',
#  'al sentarse',
#  'peinó',
#  'cabo',
#  'de un golpe',
#  'prado',
#  'entran',
#  'cuál',
#  'volvieron',
#  'población',
#  'comerse',
#  'anda',
#  'huele',
#  'hijo mayor',
#  'casaría',
#  'por la tarde',
#  'insistir',
#  'amo',
#  'preparar',
#  'mirar por',
#  'caudillo',
#  'niña',
#  'atrevió',
#  'hablaremos',
#  'del',
#  'dominio',
#  'miseria',
#  'levantó',
#  'cae',
#  'resignar',
#  'a orillas',
#  'construyese',
#  'empuñar',
#  'tiritando',
#  'mañana',
#  'ingenuamente',
#  'encender',
#  'comen',
#  'golpear',
#  'palabra',
#  'capitán',
#  'llévense',
#  'subo',
#  'diciendo',
#  'pie',
#  'consintió',
#  'comenzó',
#  'en camino',
#  'casarse',
#  'qué bien',
#  'cuarto',
#  'envió',
#  'plazo',
#  'ya que',
#  'inundaron',
#  'peana',
#  'devastaron',
#  'debo',
#  'espero',
#  'olvidar',
#  'poniente',
#  'venido',
#  'viento',
#  'oler',
#  'conozca',
#  'empezó',
#  'Pedro',
#  'explicar',
#  'espectáculo',
#  'pasmar',
#  'planta',
#  'al día siguiente',
#  'mezquino',
#  'cortesía',
#  'sospechar',
#  'trigo',
#  'bien va',
#  'ella',
#  'hacer pedazos',
#  'acompañe',
#  'feliz',
#  'pues que',
#  'brillaba',
#  'corría',
#  'porción',
#  'diga',
#  'enciende',
#  'espuela',
#  'obsequiaron',
#  'rayo',
#  'a oscuras',
#  'irrita',
#  'habían',
#  'barco',
#  'potro',
#  'perderás',
#  'España',
#  'dirigirse',
#  'lluvia',
#  'cómodo',
#  'suceso',
#  'país',
#  'hacer',
#  'es verdad',
#  'barbo',
#  'fiar',
#  '-os',
#  'sabían',
#  'salario',
#  'noticia',
#  'hallarás',
#  'zorra',
#  'blanco',
#  'frívolo',
#  'pasar',
#  'apreciaré',
#  'seor',
#  'en cambio',
#  'inflamado',
#  'puerto',
#  'lujoso',
#  'echó',
#  'compás',
#  'serpiente',
#  'cuatro',
#  'suegra',
#  'pues',
#  'recibir',
#  'tomó',
#  'tierno',
#  'continuó',
#  'convierte',
#  'calle',
#  'salvar',
#  'mi',
#  'después que',
#  'no lo hay',
#  'espada',
#  'obedecer',
#  'los suyos',
#  'conmover',
#  'entregar',
#  'hace mucho frío',
#  'valiente',
#  'primer',
#  'pillan',
#  'a las doce',
#  'el cual',
#  'mirar',
#  'llévatela',
#  'arte',
#  'mas',
#  'lucir',
#  'sujetó',
#  'llamo',
#  'sentó',
#  'volver a',
#  'pensando',
#  'he aquí',
#  'derramar',
#  'tente',
#  'aparecía',
#  'verano',
#  'conocía',
#  'vender',
#  'tapa',
#  'obsequiar',
#  'replicar',
#  'bebe',
#  'inmóvil',
#  'Alora',
#  'hay',
#  'podré',
#  'aguardando',
#  'luz',
#  'estoy',
#  'vienen',
#  'deseado',
#  'cariño',
#  'antoja',
#  'desarmar',
#  'llamarse',
#  'viene',
#  'escogió',
#  'comer',
#  ...}

# %% [markdown]
# ## Building Vocabulary from Frequency Lists

# %% [markdown]
# ## Gutenberg: An elementary spanish reader

# %%
soup_url = 'https://www.gutenberg.org/files/22065/22065-h/22065-h.htm#VOCABULARY'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ##### Cleaned up (standardized) version of the 5k words list in https://en.wiktionary.org/wiki/User:Matthias_Buchmeier/Spanish_frequency_list-1-5000

# %%
urls = [
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish1000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish1001-2000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish2001-3000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish3001-4000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish4001-5000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish5001-6000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish6001-7000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish7001-8000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish8001-9000",
    "https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/Spanish9001-10000",
]

# %%
df_list = []
for url in urls:
    html = requests.get(url).content
    soup = BeautifulSoup(html, "lxml")
    table = soup.find("tbody")
    for row in table.find_all("tr")[1:]:
        row = row.text.lower().strip().split("\n")
        df_list.append(list(filter(lambda e: e != "", row))[1:])
df = pd.DataFrame(df_list, columns = ["word", "occurrences", "lemma"])
print(df)
# Out:
#               word occurrences         lemma
# 0              que       32894           que
# 1               de       32116            de
# 2               no       29897            no
# 3                a       22313             a
# 4               la       21127            la
# ...            ...         ...           ...
# 9995         enoja           5        enojar
# 9996        empujó           5       empujar
# 9997        dilema           5        dilema
# 9998  desconectado           5  desconectado
# 9999     deprimida           5     deprimido
#
# [10000 rows x 3 columns]

# %%
a1_vocab = set(spanish1_vocab) | set(spanish2_vocab)

# %%
len(a1_vocab)
# Out:
# 3717

# %%
N = 500
print(f"What fraction of words in the top-{N} most frequent words already appear in our scraped vocabulary from Spanish 1 & 2?")
print((N - (len(a1_vocab | set(df["word"][:N])) - len(a1_vocab)))/N)
# Out:
# What fraction of words in the top-500 most frequent words already appear in our scraped vocabulary from Spanish 1 & 2?
# 0.72

# %%
a1_vocab = a1_vocab | set(df["word"][:500])
len(a1_vocab)
# Out:
# 3857
