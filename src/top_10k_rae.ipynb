# %% [markdown]
# ##### http://corpus.rae.es/frec/10000_formas.TXT

# %%
freq_dict = {}
with open("../vocab/10000_formas.TXT", encoding="iso 8859-1") as f:
    for line in f.readlines()[1:]:
        num, word, abs_freq, _ = line.strip().split("\t")
        num = int(num[:-1])
        word = word.strip()
        abs_freq = int(abs_freq.strip().replace(",", ""))
        freq_dict[num] = [word, abs_freq]

# %%
freq_dict
# Out:
# {1: ['de', 9999518],
#  2: ['la', 6277560],
#  3: ['que', 4681839],
#  4: ['el', 4569652],
#  5: ['en', 4234281],
#  6: ['y', 4180279],
#  7: ['a', 3260939],
#  8: ['los', 2618657],
#  9: ['se', 2022514],
#  10: ['del', 1857225],
#  11: ['las', 1686741],
#  12: ['un', 1659827],
#  13: ['por', 1561904],
#  14: ['con', 1481607],
#  15: ['no', 1465503],
#  16: ['una', 1347603],
#  17: ['su', 1103617],
#  18: ['para', 1062152],
#  19: ['es', 1019669],
#  20: ['al', 951054],
#  21: ['lo', 866955],
#  22: ['como', 773465],
#  23: ['más', 661696],
#  24: ['o', 542284],
#  25: ['pero', 450512],
#  26: ['sus', 449870],
#  27: ['le', 413241],
#  28: ['ha', 380339],
#  29: ['me', 374368],
#  30: ['si', 327480],
#  31: ['sin', 298383],
#  32: ['sobre', 289704],
#  33: ['este', 285461],
#  34: ['ya', 274177],
#  35: ['entre', 267493],
#  36: ['cuando', 257272],
#  37: ['todo', 247340],
#  38: ['esta', 238841],
#  39: ['ser', 232924],
#  40: ['son', 232415],
#  41: ['dos', 228439],
# ...

# %%
freq_dict[10000]
# Out:
# ['normalización', 1182]
